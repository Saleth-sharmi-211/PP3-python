# %% [markdown]
# <a href="https://colab.research.google.com/github/Saleth-sharmi-211/PP3-python/blob/main/Lab1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
principal=7800
rateofinterest=7.7
time=26
interest=(principal*rateofinterest*time)/100
print(interest)
# Out:
# 15615.6

# %%
year=int(input("enter the year:"))
if year%4==0 and year%100!=0:
 print("this is a leap year")
elif year%400==0:
  print("this is a leap year")
else:
  print("this is not a leap year")
# Out:
# enter the year:2024
# this is a leap year

# %%
n=5
for i in range (n,0,-1):
  print("*"*i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
print("menu driven calculator2")
print("1.addition")
print("2.subtraction")
print("3.multiplication")
print("4.division")
a=float(input("enter the number1:"))
b=float(input("enter the number2:"))
choice=int(input("enter the choice:"))
if choice==1:
 print("result",a+b)
elif choice==2:
 print("result",a-b)
elif choice==3:
 print("result",a*b)
elif choice==4:
  if b<a:
    print("result",a/b)
  else:
    print("not divisible")
else:
  print("invalid")
# Out:
# menu driven calculator2
# 1.addition
# 2.subtraction
# 3.multiplication
# 4.division
# enter the number1:20
# enter the number2:10
# enter the choice:4
# result 2.0
