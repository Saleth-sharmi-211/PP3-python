# %% [markdown]
# <a href="https://colab.research.google.com/github/Saleth-sharmi-211/PP3-python/blob/main/Lab1cfunction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def square(num):
 return num**2
object_=square(6)
print("square of a number",object_)
# Out:
# square of a number 36

# %%
def a(string):
  "this prints the value of length of string"
  return len(string)
print("lenth of the string:",a("functions"))
print("length of the string is",a("python"))
# Out:
# lenth of the string: 9
# length of the string is 6

# %%
def square(item):
 square=[]
 for l in item:
  square.append(l**2)
 return square
myitem=[4,6,7]
result=square(myitem)
print(result)
# Out:
# [16, 36, 49]

# %%
def a(n1,n2=20):
  print("num1:",n1)
  print("num2:",n2)
print("passing 1 argument")
a(10)
print("pass 2")
a(40,10)
# Out:
# passing 1 argument
# num1: 10
# num2: 20
# pass 2
# num1: 40
# num2: 10

# %%
def a(n1,n2):
 print("num1",n1)
 print("num2",n2)
a(10,20)
print("using key")
a(n1=40,n2=60)
# Out:
# num1 10
# num2 20
# using key
# num1 40
# num2 60

# %%
def function(*args):
 ans=[]
 for l in args:
  ans.append(l.upper())
 return ans
object=function('python','java','c')
print(object)
# Out:
# ['PYTHON', 'JAVA', 'C']

# %%
def function(**kargs):
  ans=[]
  for key,value in kargs.items():
    ans.append([key,value])
  return ans
object =function(first="python",second="functions",third="tutorial")
print(object)
# Out:
# [['first', 'python'], ['second', 'functions'], ['third', 'tutorial']]

# %%
def square(num):
  num**2
print(square(3))
# Out:
# None

# %%
def square(num):
  return num**2
print(square(3))
# Out:
# 9
